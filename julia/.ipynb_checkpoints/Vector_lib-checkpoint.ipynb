# %%
module Draw
using PyPlot
Fig,ax = missing,missing
vec= []
scale = 1
x_lim = [0,5]
y_lim = [0,5]
function draw_init end


function set_xyLabel end
function set_title end
function set_lim end
function set_scale end
function set_3d end
function drawing end

function clear_vec end
function del_vec end
function add_vec end 

mutable struct _Vector
    col::String
    vec::Vector
    function _Vector end
    
    _Vector(x::String,y::Vector) = new(x,y)
    _Vector() = _Vector("",[])
    _Vector(x::Vector) = _Vector("black",x)
    _Vector(y::String) = _Vector(y,[])
end

end
# Out:
# WARNING: replacing module Draw.
# Main.Draw

# %%
function Draw.set_lim(;x_lim = Draw.x_lim::Vector,y_lim = Draw.y_lim::Vector)
    Draw.ax.set_xlim(x_lim)
    Draw.ax.set_ylim(y_lim)
end

function Draw.set_lim(x_lim = Draw.x_lim::Vector,y_lim = Draw.ylim::Vector)
    Draw.ax.set_xlim(x_lim)
    Draw.ax.set_ylim(y_lim)
end


function Draw.set_xyLabel(X = "X",Y ="Y")
        Draw.plt.xlabel(X)
        Draw.plt.ylabel(Y)
end

function Draw.set_scale(scale)
    Draw.scale = scale
end

# %%
function Draw.del_vec(vec)
    for i in 1:length(Draw.vec)
        if i ==Draw.vec[i]
            delete!(Draw.vec,i)
            break
        end
    end
end

function Draw.clear_vec()
    Draw.vec = []
end
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
function Draw.drawing()
    #last = Draw.vec[end]
    #print(last[begin][1])
    #print(last[begin][1]," ",last[begin][2]," ",last[end],'\n')
    #Draw.ax.quiver(0,0,last[begin][1],last[begin][2],angles = "xy",scale_units = "xy",scale = Draw.scale,color = last[end])
        
    for i in 1:length(Draw.vec)
        last = Draw.vec[i]
        #print(last,'\n')
        Draw.ax.quiver(0,0,last[begin][1],last[begin][2],angles = "xy",scale_units = "xy",scale = Draw.scale,color = last[end])
        
    end     
end
# Out:
# WARNING: replacing module Vector.
# TypeError: in Vec, in type definition, expected Type, got a value of type Module
#
# Stacktrace:
#  [1] top-level scope
#    @ In[2]:2

# %%
function Draw.add_vec(vec)#vec 存储坐标与颜色
    
    flag = 0
    for i in vec
        if length(i)!=2 && length(i[1])!=2
            flag = 1
            break
        end
    end
        
    if flag == 1
        print("input error")
    end
        
    for i in vec
        push!(Draw.vec,i)
        #print(Draw.vec,"\n")
    end
end
Draw.add_vec() = Draw.add_vec([[[1,2],"black"]])
# Out:
# MethodError: no method matching Main.Draw._Vector(::Int64)
#
# Closest candidates are:
#   Main.Draw._Vector()
#    @ Main.Draw In[7]:24
#   Main.Draw._Vector(::Base.Vector)
#    @ Main.Draw In[7]:25
#   Main.Draw._Vector(::String)
#    @ Main.Draw In[7]:26
#   ...
#
#
# Stacktrace:
#  [1] top-level scope
#    @ In[12]:1

# %%
function Draw.draw_init()
    Draw.vec = []
    Draw.Fig,Draw.ax = Draw.plt.subplots()
    Draw.plt.grid(true)
    Draw.plt.xlabel("X")
    Draw.plt.ylabel("Y")
    Draw.x_lim = [0,5]
    Draw.y_lim = [0,5]
    Draw.ax.set_title("2d vectpr demo",color="blue")
    Draw.ax.set_xlim([-1,5])
    Draw.ax.set_ylim([-1,4])
       # print("vec init",vec)
end

# %%
function Draw.set_3d()
    ax = Draw.ax
    ax = Draw.Fig.gca(projection="3d")
    ax.set_zlabel("z")
    ax.set_title("3d vector")
    ax.set_zlim([0,6])
end
Draw.draw_init()
Draw.set_3d()
# Out:
# PyError ($(Expr(:escape, :(ccall(#= C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\pyfncall.jl:43 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'TypeError'>
# TypeError("FigureBase.gca() got an unexpected keyword argument 'projection'")
#
#
# Stacktrace:
#   [1] pyerr_check
#     @ C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\exception.jl:75 [inlined]
#   [2] pyerr_check
#     @ C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\exception.jl:79 [inlined]
#   [3] _handle_error(msg::String)
#     @ PyCall C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\exception.jl:96
#   [4] macro expansion
#     @ C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\exception.jl:110 [inlined]
#   [5] #107
#     @ C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\pyfncall.jl:43 [inlined]
#   [6] disable_sigint
#     @ .\c.jl:473 [inlined]
#   [7] __pycall!
#     @ C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\pyfncall.jl:42 [inlined]
#   [8] _pycall!(ret::PyCall.PyObject, o::PyCall.PyObject, args::Tuple{}, nargs::Int64, kw::PyCall.PyObject)
#     @ PyCall C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\pyfncall.jl:29
#   [9] _pycall!
#     @ C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\pyfncall.jl:11 [inlined]
#  [10] (::PyCall.PyObject)(; kwargs::Base.Pairs{Symbol, String, Tuple{Symbol}, NamedTuple{(:projection,), Tuple{String}}})
#     @ PyCall C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\pyfncall.jl:86
#  [11] kwcall(::NamedTuple{(:projection,), Tuple{String}}, ::PyCall.PyObject)
#     @ PyCall C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\pyfncall.jl:86
#  [12] set_3d()
#     @ Main .\In[25]:3
#  [13] top-level scope
#     @ In[25]:9

# %%
using Plots
n = 50
x = range(-3; stop=3, length=n)
y = x

Plots.surface(x)
# Out:
#  ***   ALL COLLINEAR DATA POINTS.
#    NDP =   50
#  ERROR DETECTED IN ROUTINE   IDTANG.

# %%
#=
#using NBInclude
#@nbinclude("Vector_lib.ipynb")
#=
=#
Draw.draw_init()
a=[[[1,2],"blue"],[[2,3],"black"]]
Draw.add_vec()
Draw.set_lim([0,5],[0,5])
Draw.drawing()

=#
# Out:
# syntax: unexpected "="
#
# Stacktrace:
#  [1] top-level scope
#    @ In[6]:1

# %%
#=
using PyCall#""一句 """"""一段
py"""
def output():
    n = input('请输入个数')
    l = []
    n = int(n)
    for i in range(n):
        s = input('请输入x,y坐标与颜色并用空格隔开')
        s = s.split(' ')
        s = [[s[0],s[1]],s[2]]
        l.append(l)
    return 0
"""
output() = py"output"()
n = py"input()"
```
=#
# Out:
# LoadError: parsing command `using PyCall#""一句 """"""一段
# py"""
# def output():
#     n = input('请输入个数')
#     l = []
#     n = int(n)
#     for i in range(n):
#         s = input('请输入x,y坐标与颜色并用空格隔开')
#         s = s.split(' ')
#         s = [[s[0],s[1]],s[2]]
#         l.append(l)
#     return 0
# """
# output() = py"output"()
# n = py"input()"
# `: special characters "#{}()[]<>|&*?~;" must be quoted in commands
# in expression starting at In[10]:1
#
# Stacktrace:
#  [1] error(s::String)
#    @ Base .\error.jl:35
#  [2] shell_parse(str::String, interpolate::Bool; special::String, filename::String)
#    @ Base .\shell.jl:116
#  [3] kwcall(::NamedTuple{(:special, :filename), Tuple{String, String}}, ::typeof(Base.shell_parse), str::String)
#    @ Base .\shell.jl:19
#  [4] var"@cmd"(__source__::LineNumberNode, __module__::Module, str::Any)
#    @ Base .\cmd.jl:493

# %%
#=
using PyCall
py"""
import numpy as np

def one(x):
return np.sin(x) ** 2 + np.cos(x) ** 2
def hello_world(s):
return s +" hello world!"
"""
helloworld(s) = py"hello_world"(s)
=#
# Out:
# PyError ($(Expr(:escape, :(ccall(#= C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\pyeval.jl:34 =# @pysym(:Py_CompileString), PyPtr, (Cstring, Cstring, Cint), s, fname, input_type))))) <class 'IndentationError'>
# IndentationError('expected an indented block after function definition on line 3', ('C:\\Users\\cloudann\\.julia\\packages\\PyCall\\twYvK\\src\\pyeval.jl', 4, 1, '\n', 4, 7))
#
#
# Stacktrace:
#  [1] pyerr_check
#    @ C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\exception.jl:75 [inlined]
#  [2] pyerr_check
#    @ C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\exception.jl:79 [inlined]
#  [3] _handle_error(msg::String)
#    @ PyCall C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\exception.jl:96
#  [4] macro expansion
#    @ C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\exception.jl:110 [inlined]
#  [5] pyeval_(s::String, globals::PyDict{String, PyObject, true}, locals::PyDict{String, PyObject, true}, input_type::Int64, fname::String)
#    @ PyCall C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\pyeval.jl:34
#  [6] top-level scope
#    @ C:\Users\cloudann\.julia\packages\PyCall\twYvK\src\pyeval.jl:230
